# %%
import pandas as pd
import numpy as np

# %%
WB_Data_df = pd.read_excel("/Users/cpt.flippers/Documents/CS 368/Project/SQL DDL/WBData.xlsx", sheet_name="Data")
WB_Country_df = pd.read_excel("/Users/cpt.flippers/Documents/CS 368/Project/SQL DDL/WBData.xlsx", sheet_name="Country")
ESG_Data_df = pd.read_excel("/Users/cpt.flippers/Documents/CS 368/Project/SQL DDL/ESGEXCEL.xlsx", sheet_name="Data")
CA_Data_df = pd.read_excel("/Users/cpt.flippers/Documents/CS 368/Project/SQL DDL/RawClimateAgreements.xlsx")

WB_Data_df.set_index('Country code', inplace=True)
WB_Country_df.set_index('Country code', inplace=True)
ESG_Data_df.set_index('Country Code', inplace=True)
CA_Data_df.set_index('Country', inplace=True)

WB_Data_df = WB_Data_df.replace('..', "NULL")
WB_Country_df = WB_Country_df.replace('..', "NULL")
ESG_Data_df = ESG_Data_df.replace('..', "NULL")
CA_Data_df = CA_Data_df.fillna('NULL')

# %%
WB_Data_df.head()
# Out:
#              Country name     Series code  \
# Country code
# ABW                 Aruba  AG.LND.EL5M.ZS
# ADO               Andorra  AG.LND.EL5M.ZS
# AFG           Afghanistan  AG.LND.EL5M.ZS
# AGO                Angola  AG.LND.EL5M.ZS
# ALB               Albania  AG.LND.EL5M.ZS
#
#                                       Series name SCALE Decimals      1990  \
# Country code
# ABW           Land area below 5m (% of land area)     0        1  29.57481
# ADO           Land area below 5m (% of land area)     0        1         0
# AFG           Land area below 5m (% of land area)     0        1         0
# AGO           Land area below 5m (% of land area)     0        1  0.208235
# ALB           Land area below 5m (% of land area)     0        1  4.967875
#
#               1991  1992  1993  1994  ...  2002  2003  2004  2005  2006  2007  \
# Country code                          ...
# ABW           NULL  NULL  NULL  NULL  ...  NULL  NULL  NULL  NULL  NULL  NULL
# ADO           NULL  NULL  NULL  NULL  ...  NULL  NULL  NULL  NULL  NULL  NULL
# AFG           NULL  NULL  NULL  NULL  ...  NULL  NULL  NULL  NULL  NULL  NULL
# AGO           NULL  NULL  NULL  NULL  ...  NULL  NULL  NULL  NULL  NULL  NULL
# ALB           NULL  NULL  NULL  NULL  ...  NULL  NULL  NULL  NULL  NULL  NULL
#
#               2008  2009  2010  2011
# Country code
# ABW           NULL  NULL  NULL  NULL
# ADO           NULL  NULL  NULL  NULL
# AFG           NULL  NULL  NULL  NULL
# AGO           NULL  NULL  NULL  NULL
# ALB           NULL  NULL  NULL  NULL
#
# [5 rows x 27 columns]
